# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from common import show_images, figure_out_device
from scratch import get_tain_dataloader, train

# %%
device = figure_out_device()
net = train(n_epochs=10, device=device)
# Out:
# Finished epoch 0. Average loss for this epoch: 0.025399
# Finished epoch 1. Average loss for this epoch: 0.019891
# Finished epoch 2. Average loss for this epoch: 0.018052
# Finished epoch 3. Average loss for this epoch: 0.017551
# Finished epoch 4. Average loss for this epoch: 0.016816
# Finished epoch 5. Average loss for this epoch: 0.016633
# Finished epoch 6. Average loss for this epoch: 0.016272
# Finished epoch 7. Average loss for this epoch: 0.016301
# Finished epoch 8. Average loss for this epoch: 0.015989
# Finished epoch 9. Average loss for this epoch: 0.015811

# %%
import torchvision
from scratch import sample_images
from matplotlib import pyplot as plt

n_steps = 40
pred_output_history, step_history = sample_images(n_steps=n_steps, batch_size=8, device=device, net=net)

fig, axs = plt.subplots(n_steps, 2, figsize=(9, 32), sharex=True)
axs[0, 0].set_title('x (model input)')
axs[0, 1].set_title('model prediction')
for i in range(n_steps):
    axs[i, 0].imshow(torchvision.utils.make_grid(step_history[i])[0].clip(0, 1), cmap='Greys')
    axs[i, 1].imshow(torchvision.utils.make_grid(pred_output_history[i])[0].clip(0, 1), cmap='Greys')
